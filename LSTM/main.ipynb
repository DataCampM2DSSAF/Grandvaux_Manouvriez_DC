# %%
import sys
import pandas as pd
import numpy as np
import sklearn as sk
import tensorflow as tf
import tensorflow.keras
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {tensorflow.keras.__version__}")
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print(tf.config.list_physical_devices('GPU'))
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers, datasets
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from sklearn.metrics import accuracy_score
from time import time
# Out:
# TensorFlow version: 2.4.1
# Keras version: 2.4.0
# Python 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]
# Pandas 1.1.5
# Scikit-Learn 0.22.2.post1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
train = pd.read_json('train.json', lines=True)
test = pd.read_json('test.json', lines=True)
test.head()
# Out:
#    index            id  ... seq_length seq_scored
# 0      0  id_00073f8be  ...        107         68
# 1      1  id_000ae4237  ...        130         91
# 2      2  id_00131c573  ...        107         68
# 3      3  id_00181fd34  ...        107         68
# 4      4  id_0020473f7  ...        130         91
#
# [5 rows x 7 columns]

# %%
def process_seq(train):
    # processes les 3 sequences and the target
    seq = train.loc[:, 'sequence'].values
    struct = train.loc[:, 'structure'].values
    loop = train.loc[:, 'predicted_loop_type'].values
    y_train = train.loc[:, ['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']]

    new_seq = []
    new_struct = []
    new_loop = []
    new_target = np.zeros([2400, 5, 68])

    for i in range(seq.shape[0]):
        # sequence processing
        seq_dic = {'A': 0, 'C': 1, 'G': 2, 'U': 3}
        n_seq = [seq_dic[l] for l in seq[i]]
        new_seq.append(n_seq)

        # structure processing
        struct_dic = {'(': 0, '.': 1, ')': 2}
        n_struct = [struct_dic[l] for l in struct[i]]
        new_struct.append(n_struct)

        # predicted_loop_type processing
        loop_dic = {'S':0, 'M':1, 'I':2, 'B':3, 'H':4, 'E':5, 'X':6}
        n_loop = [loop_dic[l] for l in loop[i]]
        new_loop.append(n_loop)

        # target processing
        new_target[i, :, :] = np.concatenate(y_train.values[i]).reshape(5, 68)

    return np.array(new_seq), np.array(new_struct), np.array(new_loop), new_target

seq, struct, loop, target = process_seq(train)

# %%
# reshape to concatenate last axis with the other features
seq = seq.reshape(seq.shape[0], seq.shape[1], 1) 
struct = struct.reshape(struct.shape[0], struct.shape[1], 1)
loop = loop.reshape(loop.shape[0], loop.shape[1], 1)
# (n_obs * seq_length * feature)
features = np.concatenate([seq, struct], axis=2)
print(features.shape)
print(target.shape)
# Out:
# (2400, 107, 2)
# (2400, 5, 68)

# %%
# prepare data
# test data will only serve for sample submission.
# we have to split our train into train and valid
X_train = features
y_train = np.swapaxes(target, 1, 2)
train_size = int(len(X_train)*0.80)
# we take only the first 68 values of the seq
X_train, X_valid = X_train[:train_size, :68, :], X_train[train_size:, :68, :]
y_train, y_valid = y_train[:train_size, :68, :], y_train[train_size:, :68, :]
print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (1920, 68, 2)
# (480, 68, 2)
# (1920, 68, 5)
# (480, 68, 5)

# %%
# create LSTM model
clear_session()

model = Sequential()
model.add(LSTM(units=50, 
               activation='tanh', 
               kernel_initializer='glorot_normal',  # xavier normal initialization
               return_sequences=True,
               input_shape=(X_train.shape[1], X_train.shape[2])))  # input shape = (68, 3)
model.add(Dropout(0.2))
model.add(LSTM(units=50, 
               activation='tanh', 
               return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(5, activation='relu'))  # output_shape = (68, 5)

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()

checkpoint_filepath = 'checkpoint_file'
checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,
                             monitor='val_loss',
                             mode='min',
                             save_weights_only=True,
                             save_best_only=True)

history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), 
                    epochs=100, batch_size=128, verbose=1, callbacks=[checkpoint])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 68, 50)            10600
# _________________________________________________________________
# dropout (Dropout)            (None, 68, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 68, 50)            20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 68, 50)            0
# _________________________________________________________________
# dense (Dense)                (None, 68, 5)             255
# =================================================================
# Total params: 31,055
# Trainable params: 31,055
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 15/15 [==============================] - 3s 73ms/step - loss: 1.0004 - val_loss: 1.0745
# Epoch 2/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.8929 - val_loss: 1.0652
# Epoch 3/100
# 15/15 [==============================] - 0s 12ms/step - loss: 1.0120 - val_loss: 1.0573
# Epoch 4/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.9365 - val_loss: 1.0499
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 1.0066 - val_loss: 1.0422
# Epoch 6/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8407 - val_loss: 1.0332
# Epoch 7/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8892 - val_loss: 1.0249
# Epoch 8/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9148 - val_loss: 1.0161
# Epoch 9/100
# 15/15 [==============================] - 0s 13ms/step - loss: 1.0269 - val_loss: 1.0076
# Epoch 10/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8726 - val_loss: 0.9982
# Epoch 11/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8548 - val_loss: 0.9903
# Epoch 12/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8742 - val_loss: 0.9848
# Epoch 13/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7938 - val_loss: 0.9803
# Epoch 14/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8329 - val_loss: 0.9774
# Epoch 15/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8026 - val_loss: 0.9762
# Epoch 16/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7447 - val_loss: 0.9754
# Epoch 17/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.9770 - val_loss: 0.9744
# Epoch 18/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9253 - val_loss: 0.9745
# Epoch 19/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8147 - val_loss: 0.9725
# Epoch 20/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7922 - val_loss: 0.9717
# Epoch 21/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8858 - val_loss: 0.9720
# Epoch 22/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7895 - val_loss: 0.9706
# Epoch 23/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8552 - val_loss: 0.9705
# Epoch 24/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8609 - val_loss: 0.9688
# Epoch 25/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7892 - val_loss: 0.9677
# Epoch 26/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7818 - val_loss: 0.9671
# Epoch 27/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8812 - val_loss: 0.9678
# Epoch 28/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7659 - val_loss: 0.9678
# Epoch 29/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9444 - val_loss: 0.9671
# Epoch 30/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8103 - val_loss: 0.9655
# Epoch 31/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7916 - val_loss: 0.9650
# Epoch 32/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.9276 - val_loss: 0.9654
# Epoch 33/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.9030 - val_loss: 0.9643
# Epoch 34/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8188 - val_loss: 0.9636
# Epoch 35/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7664 - val_loss: 0.9640
# Epoch 36/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8988 - val_loss: 0.9630
# Epoch 37/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7945 - val_loss: 0.9626
# Epoch 38/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8861 - val_loss: 0.9649
# Epoch 39/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9153 - val_loss: 0.9620
# Epoch 40/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8045 - val_loss: 0.9616
# Epoch 41/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8861 - val_loss: 0.9621
# Epoch 42/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7972 - val_loss: 0.9651
# Epoch 43/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8376 - val_loss: 0.9608
# Epoch 44/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6947 - val_loss: 0.9604
# Epoch 45/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8787 - val_loss: 0.9638
# Epoch 46/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8278 - val_loss: 0.9601
# Epoch 47/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6933 - val_loss: 0.9605
# Epoch 48/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8812 - val_loss: 0.9606
# Epoch 49/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.9115 - val_loss: 0.9597
# Epoch 50/100
# 15/15 [==============================] - 0s 12ms/step - loss: 1.0221 - val_loss: 0.9598
# Epoch 51/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9063 - val_loss: 0.9587
# Epoch 52/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7714 - val_loss: 0.9603
# Epoch 53/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8530 - val_loss: 0.9596
# Epoch 54/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9205 - val_loss: 0.9579
# Epoch 55/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8729 - val_loss: 0.9581
# Epoch 56/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.7698 - val_loss: 0.9597
# Epoch 57/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7728 - val_loss: 0.9616
# Epoch 58/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8048 - val_loss: 0.9587
# Epoch 59/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.8220 - val_loss: 0.9572
# Epoch 60/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8343 - val_loss: 0.9588
# Epoch 61/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7559 - val_loss: 0.9574
# Epoch 62/100
# 15/15 [==============================] - 0s 13ms/step - loss: 1.0286 - val_loss: 0.9582
# Epoch 63/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8162 - val_loss: 0.9569
# Epoch 64/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8249 - val_loss: 0.9577
# Epoch 65/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9299 - val_loss: 0.9573
# Epoch 66/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8516 - val_loss: 0.9574
# Epoch 67/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8175 - val_loss: 0.9608
# Epoch 68/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8138 - val_loss: 0.9566
# Epoch 69/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.9417 - val_loss: 0.9573
# Epoch 70/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7407 - val_loss: 0.9571
# Epoch 71/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8375 - val_loss: 0.9585
# Epoch 72/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8724 - val_loss: 0.9566
# Epoch 73/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7602 - val_loss: 0.9581
# Epoch 74/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8762 - val_loss: 0.9586
# Epoch 75/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8316 - val_loss: 0.9579
# Epoch 76/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8788 - val_loss: 0.9576
# Epoch 77/100
# 15/15 [==============================] - 0s 12ms/step - loss: 1.0007 - val_loss: 0.9580
# Epoch 78/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7643 - val_loss: 0.9568
# Epoch 79/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7831 - val_loss: 0.9568
# Epoch 80/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7092 - val_loss: 0.9564
# Epoch 81/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.8933 - val_loss: 0.9569
# Epoch 82/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6975 - val_loss: 0.9570
# Epoch 83/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8826 - val_loss: 0.9557
# Epoch 84/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7299 - val_loss: 0.9574
# Epoch 85/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8211 - val_loss: 0.9566
# Epoch 86/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.7426 - val_loss: 0.9564
# Epoch 87/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7566 - val_loss: 0.9562
# Epoch 88/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7852 - val_loss: 0.9568
# Epoch 89/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9100 - val_loss: 0.9584
# Epoch 90/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8815 - val_loss: 0.9565
# Epoch 91/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7672 - val_loss: 0.9560
# Epoch 92/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8772 - val_loss: 0.9584
# Epoch 93/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8990 - val_loss: 0.9580
# Epoch 94/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8634 - val_loss: 0.9564
# Epoch 95/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.7667 - val_loss: 0.9571
# Epoch 96/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.9544 - val_loss: 0.9565
# Epoch 97/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.8360 - val_loss: 0.9543
# Epoch 98/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8403 - val_loss: 0.9567
# Epoch 99/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7137 - val_loss: 0.9578
# Epoch 100/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.8854 - val_loss: 0.9543

# %%
model.load_weights('checkpoint_file')  # load best model
mse = model.evaluate(X_valid, y_valid)
print(mse)

def plot_history(history):
    # plot history of CNN training
    plt.figure(figsize=(25, 12))
    plt.plot(history.history['loss'], color='pink', label='train')
    plt.plot(history.history['val_loss'], color='red', label='valid')
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='lower right')
    plt.grid(color='grey')
    plt.show()

plot_history(history)

#model.predict(X_train[0,:,:])
# Out:
# 15/15 [==============================] - 0s 3ms/step - loss: 0.9439
# 0.9438894391059875

# %%
model.predict(X_train)[0]
# Out:
# array([[0.5655458 , 0.5953725 , 2.0016396 , 0.4824934 , 0.5741792 ],
#        [1.4976876 , 2.066843  , 2.9260724 , 2.042563  , 1.8419563 ],
#        [1.1197884 , 0.7687284 , 0.91171384, 0.98218346, 1.0187368 ],
#        [0.84447336, 0.61607164, 0.7569084 , 0.785345  , 0.7850028 ],
#        [0.71273947, 0.71160704, 0.787045  , 0.85444957, 0.78006965],
#        [0.31920537, 0.41196096, 0.46776763, 0.4659025 , 0.4901519 ],
#        [0.19553861, 0.4697823 , 0.43931383, 0.35281512, 0.4771916 ],
#        [0.09009606, 0.34417504, 0.32377672, 0.23362124, 0.3913712 ],
#        [0.13723867, 0.3539289 , 0.25491253, 0.1802454 , 0.3377816 ],
#        [0.01783507, 0.24341603, 0.18568239, 0.14365014, 0.26480648],
#        [0.1109817 , 0.27238202, 0.14799237, 0.14480427, 0.22140983],
#        [0.7121215 , 0.5416237 , 0.3896544 , 0.466851  , 0.5373431 ],
#        [0.8126633 , 0.64248455, 0.51049036, 0.60101193, 0.6606075 ],
#        [0.81671965, 0.82398164, 0.7067441 , 0.71813446, 0.7427177 ],
#        [0.7580224 , 0.7022572 , 0.56386983, 0.68370146, 0.71775484],
#        [0.66060746, 0.6354802 , 0.551939  , 0.6390452 , 0.70154643],
#        [0.46166888, 0.6140001 , 0.54447955, 0.55835044, 0.63720614],
#        [0.51973784, 0.4772743 , 0.4008497 , 0.4751677 , 0.55791533],
#        [0.18546493, 0.31231183, 0.30320898, 0.23201072, 0.3536121 ],
#        [0.13816354, 0.323636  , 0.19262502, 0.20728391, 0.25596923],
#        [0.25881112, 0.3154007 , 0.210973  , 0.27300447, 0.3381072 ],
#        [0.16457629, 0.36722496, 0.2837026 , 0.257802  , 0.34163862],
#        [0.5588412 , 0.55559826, 0.451652  , 0.5120108 , 0.52427644],
#        [0.21526381, 0.39307112, 0.38973266, 0.34075812, 0.39986315],
#        [0.2940682 , 0.43364578, 0.3895843 , 0.3273197 , 0.357616  ],
#        [0.5349598 , 0.57871693, 0.5200459 , 0.52840215, 0.54068077],
#        [0.0982746 , 0.27333373, 0.253448  , 0.17248204, 0.22544846],
#        [0.00755655, 0.18262866, 0.19699965, 0.10616291, 0.14782906],
#        [0.51562184, 0.47834903, 0.42600864, 0.4502173 , 0.4830486 ],
#        [0.39869133, 0.49354413, 0.45952404, 0.4125842 , 0.4388812 ],
#        [0.5282345 , 0.53273976, 0.49280986, 0.4374166 , 0.43230593],
#        [0.4972787 , 0.5150803 , 0.4592347 , 0.4864353 , 0.47865513],
#        [0.3319678 , 0.48767757, 0.45831022, 0.42713737, 0.43881708],
#        [0.0292073 , 0.18418337, 0.15766054, 0.11292447, 0.15887803],
#        [0.23895328, 0.28101778, 0.25323483, 0.23239139, 0.28508285],
#        [0.53493106, 0.44833043, 0.36446822, 0.4497717 , 0.45404455],
#        [0.60923755, 0.5892141 , 0.55465674, 0.52030116, 0.52115077],
#        [0.2604379 , 0.29137442, 0.30605358, 0.2810062 , 0.3184078 ],
#        [0.3766862 , 0.39499485, 0.39959797, 0.4044543 , 0.4546335 ],
#        [0.16744104, 0.32008573, 0.26005292, 0.31872648, 0.33344692],
#        [0.20960526, 0.28158775, 0.2752761 , 0.25394586, 0.32974783],
#        [0.1990459 , 0.26711968, 0.1608684 , 0.2424508 , 0.28462416],
#        [0.11883039, 0.2850227 , 0.23793969, 0.20192102, 0.29733795],
#        [0.48346487, 0.43035907, 0.31063217, 0.34508604, 0.38030678],
#        [0.62324953, 0.541228  , 0.460473  , 0.45158845, 0.4466599 ],
#        [0.53897727, 0.473217  , 0.38616365, 0.4272735 , 0.43249208],
#        [0.4783509 , 0.44312492, 0.4037775 , 0.41030896, 0.4639362 ],
#        [0.1388458 , 0.2716597 , 0.3014263 , 0.24531794, 0.2696634 ],
#        [0.2231733 , 0.35599807, 0.31401303, 0.24660134, 0.28262392],
#        [0.142221  , 0.3648119 , 0.2606837 , 0.22870505, 0.24769175],
#        [0.09796419, 0.3150958 , 0.2241001 , 0.17558962, 0.2086441 ],
#        [0.17679274, 0.29134604, 0.20492771, 0.22396079, 0.2288107 ],
#        [0.19364038, 0.29479215, 0.22691993, 0.2738602 , 0.2743925 ],
#        [0.55895126, 0.5910578 , 0.48903668, 0.5004623 , 0.5055235 ],
#        [0.49979827, 0.5276883 , 0.44120082, 0.4976412 , 0.47837052],
#        [0.28950793, 0.37050816, 0.3899206 , 0.41069996, 0.41386262],
#        [0.10050905, 0.3902707 , 0.38586295, 0.37391767, 0.3670897 ],
#        [0.30524075, 0.45772243, 0.41184294, 0.40289897, 0.38812625],
#        [0.32763758, 0.48017934, 0.44668514, 0.40948826, 0.4018133 ],
#        [0.41819832, 0.4828823 , 0.45701483, 0.45099467, 0.45080435],
#        [0.5533296 , 0.69126755, 0.6471695 , 0.590287  , 0.60470957],
#        [0.46819663, 0.5445598 , 0.50226265, 0.52949095, 0.5367952 ],
#        [0.1392671 , 0.3817394 , 0.44254822, 0.39341646, 0.384202  ],
#        [0.08353166, 0.3670184 , 0.38981342, 0.35000753, 0.32191947],
#        [0.40685984, 0.47386694, 0.4539188 , 0.4618293 , 0.42335582],
#        [0.37776324, 0.5980319 , 0.57708335, 0.5241945 , 0.4982725 ],
#        [0.30681232, 0.51023173, 0.49450272, 0.45686418, 0.4206673 ],
#        [0.38607624, 0.476874  , 0.46672463, 0.45377547, 0.43560338]],
#       dtype=float32)

# %%
sample_sub = pd.read_csv('sample_submission.csv', sep=',')
rng = np.random.normal(2, 0.2, (457953, 5))
sample_sub.iloc[:, 1:] = rng
sample_sub[0:10]
# Out:
#         id_seqpos  reactivity  deg_Mg_pH10  deg_pH10  deg_Mg_50C   deg_50C
# 0  id_00073f8be_0    2.073513     1.951734  1.945810    2.033376  2.063232
# 1  id_00073f8be_1    2.029750     2.163283  2.214269    2.162002  2.028075
# 2  id_00073f8be_2    1.717368     2.061842  1.845021    1.852701  2.132514
# 3  id_00073f8be_3    2.010813     1.928485  2.069491    2.282164  2.418024
# 4  id_00073f8be_4    1.920599     1.974127  2.068043    1.729365  2.006571
# 5  id_00073f8be_5    2.151393     2.124969  1.759833    2.105465  2.151309
# 6  id_00073f8be_6    1.992442     1.954734  1.796370    2.089301  1.907396
# 7  id_00073f8be_7    2.029633     1.658533  1.672325    2.091965  1.790797
# 8  id_00073f8be_8    2.019208     2.221790  2.155620    2.106790  1.935207
# 9  id_00073f8be_9    2.112149     2.179876  2.180399    1.973199  2.149662

# %%
data = np.load('id_000ae4237.npy')
data.shape
plt.imshow(data)
plt.show()
data1 = np.load('27.npy')
data1.shape
plt.imshow(data1)
plt.show()
